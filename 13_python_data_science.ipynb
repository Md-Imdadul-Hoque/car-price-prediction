# %% [markdown]
# # Pandas continues

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Cross tabulation
#
# Croos tabulation is used to depict the relationship between a group of features or attributes.

# %%
df = pd.read_csv("SomervilleHappinessSurvey2015.csv", encoding="UTF-16")
df.head()
# Out:
#    D  X1  X2  X3  X4  X5  X6
# 0  0   3   3   3   4   2   4
# 1  0   3   2   3   5   4   3
# 2  1   5   3   3   3   3   5
# 3  0   5   4   3   3   3   5
# 4  0   5   4   3   3   3   5

# %% [markdown]
# D = decision attribute (D) with values 0 (unhappy) and 1 (happy)
#
# X1 = the availability of information about the city services
#
# X2 = the cost of housing
#
# X3 = the overall quality of public schools
#
# X4 = your trust in the local police
#
# X5 = the maintenance of streets and sidewalks
#
# X6 = the availability of social community events

# %%
df.rename(columns={"D": "Happiness", 
                   "X1": "City_service_info",
                  "X2": "Housing_cost",
                  "X3":"Public_school",
                  "X4":"Police_trust",
                  "X5":"Infrust_development",
                  "X6":"Community_events"}, inplace=True)
df.head()
# Out:
#    Happiness  City_service_info  Housing_cost  Public_school  Police_trust  \
# 0          0                  3             3              3             4
# 1          0                  3             2              3             5
# 2          1                  5             3              3             3
# 3          0                  5             4              3             3
# 4          0                  5             4              3             3
#
#    Infrust_development  Community_events
# 0                    2                 4
# 1                    4                 3
# 2                    3                 5
# 3                    3                 5
# 4                    3                 5

# %% [markdown]
# **df.apply method: We can manupulate the values of a same column (or a row) by this method.**

# %%
# apply method with dataframe
df.Happiness = df.Happiness.apply(lambda x:"Happy" if x==1 else "Unhappy")
df.head()
# Out:
#   Happiness  City_service_info  Housing_cost  Public_school  Police_trust  \
# 0   Unhappy                  3             3              3             4
# 1   Unhappy                  3             2              3             5
# 2     Happy                  5             3              3             3
# 3   Unhappy                  5             4              3             3
# 4   Unhappy                  5             4              3             3
#
#    Infrust_development  Community_events
# 0                    2                 4
# 1                    4                 3
# 2                    3                 5
# 3                    3                 5
# 4                    3                 5

# %%
def rate_descriptor(x):
    if x==1:
        return "Not_at_all"
    elif x==2:
        return "Unlikely"
    elif x==3:
        return "Fair"
    elif x==4:
        return "Good"
    elif x==5:
        return "Excellent"
    
for i in range(1, len(df.columns)):
    df[df.columns[i]] = df[df.columns[i]].apply(lambda x:rate_descriptor(x))
    
df.head()
# Out:
#   Happiness City_service_info Housing_cost Public_school Police_trust  \
# 0   Unhappy              Fair         Fair          Fair         Good
# 1   Unhappy              Fair     Unlikely          Fair    Excellent
# 2     Happy         Excellent         Fair          Fair         Fair
# 3   Unhappy         Excellent         Good          Fair         Fair
# 4   Unhappy         Excellent         Good          Fair         Fair
#
#   Infrust_development Community_events
# 0            Unlikely             Good
# 1                Good             Fair
# 2                Fair        Excellent
# 3                Fair        Excellent
# 4                Fair        Excellent

# %%
pd.crosstab(df.Happiness, df.Police_trust)
# Out:
# Police_trust  Excellent  Fair  Good  Not_at_all  Unlikely
# Happiness
# Happy                16    24    34           2         1
# Unhappy              10    24    26           1         5

# %%
pd.crosstab(df.Housing_cost, df.Happiness)
# Out:
# Happiness     Happy  Unhappy
# Housing_cost
# Excellent         5        2
# Fair             24       22
# Good              9       11
# Not_at_all       14       16
# Unlikely         25       15

# %%
titanic = pd.read_csv('train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.crosstab(titanic.Pclass, titanic.Survived)
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(titanic.Embarked, titanic.Survived)
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217

# %%
pd.crosstab(titanic.Embarked, titanic.Survived, margins=True)
# Out:
# Survived    0    1  All
# Embarked
# C          75   93  168
# Q          47   30   77
# S         427  217  644
# All       549  340  889

# %% [markdown]
# **Comparing with multiple element**

# %%
pd.crosstab(titanic.Embarked, [titanic.Survived, titanic.Sex, titanic.Pclass], margins=False)
# Out:
# Survived      0                           1
# Sex      female        male          female         male
# Pclass        1  2   3    1   2    3      1   2   3    1   2   3
# Embarked
# C             1  0   8   25   8   33     42   7  15   17   2  10
# Q             0  0   9    1   1   36      1   2  24    0   0   3
# S             2  6  55   51  82  231     46  61  33   28  15  34

# %% [markdown]
# **Using aggfunc and values**

# %%
pd.crosstab(titanic.Survived, titanic.Sex, values=titanic.Age, aggfunc=np.mean)
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %%
pd.crosstab?
